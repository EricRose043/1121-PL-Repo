# %%
import urllib.request as req
url='https://www.ptt.cc/bbs/Coffee/index.html'
request=req.Request(url, headers={
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36 Edg/118.0.2088.61'
})
with req.urlopen(request) as response:
    data=response.read().decode('utf-8')
print(data)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Coffee 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Coffee/index.html"><span class="board-label">看板 </span>Coffee</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# ...

# %%
import bs4
root=bs4.BeautifulSoup(data, 'html.parser')
print(root.title.string)
# Out:
# 看板 Coffee 文章列表 - 批踢踢實業坊

# %%
titles=root.find_all('div',class_='title')
print(titles)
# Out:
# [<div class="title">
# <a href="/bbs/Coffee/M.1697900020.A.1D2.html">[其它] 日本大阪咖啡代購 11/3回國寄出</a>
# </div>, <div class="title">
# <a href="/bbs/Coffee/M.1697903304.A.B1C.html">[器材] Breville BCG820與飛馬牌900n出粉品質？</a>
# </div>, <div class="title">
# <a href="/bbs/Coffee/M.1697946480.A.8A1.html">[廣宣] 推文贈 柏克斯咖啡 CR高分濾掛</a>
# </div>, <div class="title">
# <a href="/bbs/Coffee/M.1697966595.A.0D3.html">[販售] Bodum電動磨豆機（紅色）</a>
# </div>, <div class="title">
# <a href="/bbs/Coffee/M.1697969961.A.D93.html">Re: [器材] Breville BCG820與飛馬牌900n出粉品質？</a>
# </div>, <div class="title">
# <a href="/bbs/Coffee/M.1697981408.A.374.html">Re: [其它] Costco 咖啡豆推薦？</a>
# </div>, <div class="title">
# <a href="/bbs/Coffee/M.1697986081.A.583.html">[器材] 關於percolator疑問</a>
# </div>, <div class="title">
# <a href="/bbs/Coffee/M.1697990326.A.3D4.html">Fw: [新聞] 「咖啡的未來，我來守護！」星巴克研發抵禦氣候變遷新咖</a>
# </div>, <div class="title">
# <a href="/bbs/Coffee/M.1698030966.A.81E.html">[情報] 2023世界盃咖啡大師台灣選拔賽結果出爐</a>
# ...

# %%
for title in titles:
    if title.a !=None:
        print(title.a.string)
# Out:
# [其它] 日本大阪咖啡代購 11/3回國寄出
# [器材] Breville BCG820與飛馬牌900n出粉品質？
# [廣宣] 推文贈 柏克斯咖啡 CR高分濾掛
# [販售] Bodum電動磨豆機（紅色）
# Re: [器材] Breville BCG820與飛馬牌900n出粉品質？
# Re: [其它] Costco 咖啡豆推薦？
# [器材] 關於percolator疑問
# Fw: [新聞] 「咖啡的未來，我來守護！」星巴克研發抵禦氣候變遷新咖
# [情報] 2023世界盃咖啡大師台灣選拔賽結果出爐
# [販售] 小富士 鬼齒 少用
# [其它] 日本藍瓶 blue bottle 冬季限定豆團購
# [情報] 伊萊克斯極致美味500特價
# [器材] 義式磨豆機選擇
# [器材] BWT 濾水壺 & 鎂濾芯之口感心得
# Re: [器材] BWT 濾水壺 之鎂濾芯口感心得
# [情報] 「世界咖啡沖煮冠軍粕谷哲」新書分享會
# [器材] picopresso小疑問
# 《廣宣》句點珈琲來發優惠囉
# [公告] Coffee板規(新修訂2021.7.24)
# [公告] 新增板規 3.9
# [器材]十月份器材徵求文

# %%
temp = []
for title in titles:
    temp.append(title.a.string)
    
temp
# Out:
# ['[其它] 日本大阪咖啡代購 11/3回國寄出',
#  '[器材] Breville BCG820與飛馬牌900n出粉品質？',
#  '[廣宣] 推文贈 柏克斯咖啡 CR高分濾掛',
#  '[販售] Bodum電動磨豆機（紅色）',
#  'Re: [器材] Breville BCG820與飛馬牌900n出粉品質？',
#  'Re: [其它] Costco 咖啡豆推薦？',
#  '[器材] 關於percolator疑問',
#  'Fw: [新聞] 「咖啡的未來，我來守護！」星巴克研發抵禦氣候變遷新咖',
#  '[情報] 2023世界盃咖啡大師台灣選拔賽結果出爐',
#  '[販售] 小富士 鬼齒 少用',
#  '[其它] 日本藍瓶 blue bottle 冬季限定豆團購',
#  '[情報] 伊萊克斯極致美味500特價',
#  '[器材] 義式磨豆機選擇',
#  '[器材] BWT 濾水壺 & 鎂濾芯之口感心得',
#  'Re: [器材] BWT 濾水壺 之鎂濾芯口感心得',
#  '[情報] 「世界咖啡沖煮冠軍粕谷哲」新書分享會',
#  '[器材] picopresso小疑問',
#  '《廣宣》句點珈琲來發優惠囉',
#  '[公告] Coffee板規(新修訂2021.7.24)',
#  '[公告] 新增板規 3.9',
#  '[器材]十月份器材徵求文 ']

# %%
import json
import pandas as pd
df = pd.DataFrame(temp)
df.to_json('coffee.json',force_ascii=False)
temp1 = df.to_dict()
temp1
# Out:
# {0: {0: '[其它] 日本大阪咖啡代購 11/3回國寄出',
#   1: '[器材] Breville BCG820與飛馬牌900n出粉品質？',
#   2: '[廣宣] 推文贈 柏克斯咖啡 CR高分濾掛',
#   3: '[販售] Bodum電動磨豆機（紅色）',
#   4: 'Re: [器材] Breville BCG820與飛馬牌900n出粉品質？',
#   5: 'Re: [其它] Costco 咖啡豆推薦？',
#   6: '[器材] 關於percolator疑問',
#   7: 'Fw: [新聞] 「咖啡的未來，我來守護！」星巴克研發抵禦氣候變遷新咖',
#   8: '[情報] 2023世界盃咖啡大師台灣選拔賽結果出爐',
#   9: '[販售] 小富士 鬼齒 少用',
#   10: '[其它] 日本藍瓶 blue bottle 冬季限定豆團購',
#   11: '[情報] 伊萊克斯極致美味500特價',
#   12: '[器材] 義式磨豆機選擇',
#   13: '[器材] BWT 濾水壺 & 鎂濾芯之口感心得',
#   14: 'Re: [器材] BWT 濾水壺 之鎂濾芯口感心得',
#   15: '[情報] 「世界咖啡沖煮冠軍粕谷哲」新書分享會',
#   16: '[器材] picopresso小疑問',
#   17: '《廣宣》句點珈琲來發優惠囉',
#   18: '[公告] Coffee板規(新修訂2021.7.24)',
#   19: '[公告] 新增板規 3.9',
#   20: '[器材]十月份器材徵求文 '}}

# %%
import csv
with open('coffee.csv', 'w', newline='') as file:
    writer = csv.writer(file)

    # 寫入CSV文件的標題行
    writer.writerow(['文章標題'])

    # 逐一寫入temp中的數據
    for item in temp:
        writer.writerow([item])

# %%
coffeecsv = pd.read_csv('coffee.csv',encoding='Big5')
coffeecsv
# Out:
#                                      文章標題
# 0                  [其它] 日本大阪咖啡代購 11/3回國寄出
# 1       [器材] Breville BCG820與飛馬牌900n出粉品質？
# 2                   [廣宣] 推文贈 柏克斯咖啡 CR高分濾掛
# 3                     [販售] Bodum電動磨豆機（紅色）
# 4   Re: [器材] Breville BCG820與飛馬牌900n出粉品質？
# 5                  Re: [其它] Costco 咖啡豆推薦？
# 6                     [器材] 關於percolator疑問
# 7     Fw: [新聞] 「咖啡的未來，我來守護！」星巴克研發抵禦氣候變遷新咖
# 8               [情報] 2023世界盃咖啡大師台灣選拔賽結果出爐
# 9                          [販售] 小富士 鬼齒 少用
# 10          [其它] 日本藍瓶 blue bottle 冬季限定豆團購
# 11                     [情報] 伊萊克斯極致美味500特價
# 12                           [器材] 義式磨豆機選擇
# 13                [器材] BWT 濾水壺 & 鎂濾芯之口感心得
# 14              Re: [器材] BWT 濾水壺 之鎂濾芯口感心得
# 15                [情報] 「世界咖啡沖煮冠軍粕谷哲」新書分享會
# 16                     [器材] picopresso小疑問
# 17                          《廣宣》句點珈琲來發優惠囉
# 18            [公告] Coffee板規(新修訂2021.7.24)
# 19                          [公告] 新增板規 3.9
# 20                          [器材]十月份器材徵求文
